# %%
# !unzip filtered_images.zip
# Out:
# Archive:  filtered_images.zip
#   inflating: filtered_images/10000.jpg
#   inflating: filtered_images/10001.jpg
#   inflating: filtered_images/10002.jpg
#   inflating: filtered_images/10003.jpg
#   inflating: filtered_images/10004.jpg
#   inflating: filtered_images/10005.jpg
#   inflating: filtered_images/10006.jpg
#   inflating: filtered_images/10007.jpg
#   inflating: filtered_images/10008.jpg
#   inflating: filtered_images/10009.jpg
#   inflating: filtered_images/10010.jpg
#   inflating: filtered_images/10011.jpg
#   inflating: filtered_images/10012.jpg
#   inflating: filtered_images/10013.jpg
#   inflating: filtered_images/10015.jpg
#   inflating: filtered_images/10016.jpg
#   inflating: filtered_images/10017.jpg
#   inflating: filtered_images/10018.jpg
#   inflating: filtered_images/10019.jpg
#   inflating: filtered_images/10020.jpg
#   inflating: filtered_images/10021.jpg
#   inflating: filtered_images/10022.jpg
#   inflating: filtered_images/10023.jpg
# ...

# %%
import os

folder_path = 'filtered_images'

all_items = os.listdir(folder_path)

files = [item for item in all_items if os.path.isfile(os.path.join(folder_path, item))]

number_of_files = len(files)
number_of_files
# Out:
# 27932
